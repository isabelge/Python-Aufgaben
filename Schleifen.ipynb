# %% [markdown]
# # Einführung Schleifen in Python
#
# Mit diesen Aufgaben lernen Sie wie Schleifen in Python verwendet werden können.
#
# ## Aufgabe 1
# In Python können Schleifen unter anderem mit dem Schlüsselwort `for` geschrieben werden. Mit `range` kann angegeben werden wie oft die Schleife wiederholt werden soll. Es gibt verschiedene Möglichkeiten `range` zu verwenden.
#
# `range(stop_exklusiv)`
#
# `range(start, stop_exklusiv)`
#
# `range(start, stop_exklusiv, schrittgrösse)`
#
# Teste Sie die verschiedenen Möglichkeiten von `range`.
# - Wie können die Zahlen von 0 bis 10 ausgegeben werden?
# - Wie können die Zahlen von 5 bis 9 ausgegeben werden?
# - Wie können die Zahlen 8, 11 und 14 ausgegeben werden?

# %%
# Testen Sie hier die verschiedenen Möglichkeiten von range
for i in range( ):
    print("Durchlauf: ", i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Aufgabe 2
# In einer Schleife können Zahlen nicht nur hoch gezählt werden, sondern auch runter.
#
# Versuchen Sie `range` so zu programmieren, dass es mit diesem Struktogramm übereinstimmt.
#
# <img src="./pictureFor/aufgabe2.png" width="450">

# %%
# Vervollständige die range hier
for i in range( ):
    print("Durchlauf: ", i)
# Out:
#   Cell In[9], line 5
#     if :
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Aufgabe 3
# Versuchen Sie `range` so zu programmieren, dass es mit diesem Struktogramm übereinstimmt.
#
# <img src="./pictureFor/aufgabe3.png" width="450">

# %%
## Hier muss der Code geschrieben werden

# %% [markdown]
# ## Aufgabe 4
# Schreiben Sie ein Programm, das alle Zahlen von 0 bis zu einer bestimmten Zahl X ausgibt.
# - Der Benutzer*in soll die Möglichkeit haben, die Zahl X einzugeben.
# - Die Zahlen von 0 bis X werden addiert.
# - Sobald alle Zahlen ausgegeben wurden, soll das Ergebnis der Addition angezeigt werden.

# %%
## hier wird die Zahl x eingelsen
x = int(input("Bitte wähle die Zahl x."))
## Variable resultat für die Zahlen, welche addiert werden
resultat = 0

## nach dem for und vor dem ':' muss die korrekte range angegeben werden
for :
    print("Zahl: ", x)
    # hier müssen die Zahlen noch zusammengezählt werden

## hier muss das Resultat noch ausgegeben werden
# Out:
#   Cell In[8], line 7
#     for :
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Aufgabe 5
# Es soll ein Notenrechner erstellt werden.
#
# - Als Erstes soll das Programm fragen, wie viele Prüfungen geschrieben wurden.
# - Nun sollen die Noten für all diese Prüfungen entgegengenommen werden und die Semesternote berechnet werden.
# - Zum Schluss soll das Programm die Semesternote ausgeben und angeben, ob das Fach bestanden wurde oder nicht.
# (bis 4, Ungenügend, 4 und höher, Bestanden)

# %%
## Hier muss der Code geschrieben werden

# %% [markdown]
# ## Aufgabe 6
# Schreiben Sie ein Programm, welches eine Liste von Zahlen durchläuft und für jede Zahl ausgibt, ob sie gerade oder ungerade ist.
#
# Achtung, für Listen wird nicht `range` verwendet, sondern `in`.
#
# Als Erinnerung mit Modulo '`%`' kann der Rest einer Division berechnet werden. Dies kann verwendet werden, um herauszufinden, ob eine Zahl gerade oder ungerade ist.
#
# Achtung, für Listen wird nicht `range` verwendet, sondern `in`.

# %%
zahlen = [4, 7, 3, 5, 9]

## hier muss die Schleife hinzugefügt werden

# %% [markdown]
# ## Aufgabe 7
# In diesem Programm muss der Duchrschnitt über mehrere Noten berechnet werden.
#
# Achtung, die Noten sind in einer Liste gespeichert.

# %%
noten = [6, 4, 5, 3, 6, 3]
zahlenAddiert = 0

## hier muss die Schleife hinzugefügt werden, um die Noten zusammenzuzählen
for :
    zahlenAddiert =

## hier wird nun der Durchschnitt berechnet
anzahlNoten = len(noten)
durchschnitt =
# Out:
# geügend

# %% [markdown]
# ## Aufgabe 8
#
# Die Aufgabe ist die Software eines Getränke-Automaten zu schreiben. Der Getränke-Automat hat folgende Funktionalitäten:
#
# - Es gibt mehrere Getränke zur Auswahl: Wasser, Limonade und Cola.
# - Wasser kostet 1 CHF, Limonade 2 CHF und Cola 5 CHF.
# - Die Getränke werden mit Münzen bezahlt.

# %%
auswahl = int(input("Bitte wählen Sie ihr Getränk aus: 1 für Wasser, 2 für Limonade oder 3 für cola"))

## je nachdem welches Getraenk gewaehlt wurde, muss der korrekte Preis angegeben werden

geld = int(input("Bitte werfen Sie die erste Münze ein"))

## nun muss der Betrag ueberprueft werden und entweder erscheint die Meldung "Vielen Dank, bitte entnehmen Sie ihr Getraenk" oder "Es müssen noch x CHF bezahlt werden". (x gibt an wie viel noch bezahlt werden muss.)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 zahl = int(input("Bitte eine ganze Zahl eingeben: "))
#
# File ~/PyCharmMiscProject/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File ~/PyCharmMiscProject/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
# ...
